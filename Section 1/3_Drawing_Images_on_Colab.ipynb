# %% [markdown]
# <a href="https://colab.research.google.com/github/TakahiroDoi/Hands-On-Computer-Vision-with-OpenCV-4-Keras-and-TensorFlow-2/blob/master/3_Drawing_Images_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Drawing images and shapes using OpenCV
#
# Let's start off my making a black square

# %%
# Common setup cell
import sys
import os
from google.colab import drive

# Mount google drive 
drive.mount('/content/gdrive')

# Change this according to the current section
section_number = 1

# Setup to use cv.imshow() 
gDrive_location = '/content/gdrive/MyDrive'
module_folder = 'Utilities4Colab'
full_path_module_folder = os.path.join(gDrive_location, module_folder)
sys.path.append(full_path_module_folder)

# Import class and define the instance as cv (therby you can delete only '2' below)
from cv2workaround import Cv2Workaround 
cv = Cv2Workaround()

# file path
project_path = 'Hands-On-Computer-Vision-with-OpenCV-4-Keras-and-TensorFlow-2/'
str_section = 'Section ' + str(section_number)
full_path = os.path.join(gDrive_location, project_path, str_section)
print(full_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Hands-On-Computer-Vision-with-OpenCV-4-Keras-and-TensorFlow-2/Section 1

# %%
import cv2
import numpy as np

# Create a black image using numpy to create and array of black 
image = np.zeros((512,512,3), np.uint8)

# Can we make this in black and white? grayscale
image_bw = np.zeros((512,512), np.uint8)

# Black would be the same as a greyscale or color image (same for white)
cv.imshow("Black Rectangle (Color)", image)
cv.imshow("Black Rectangle (B&W)", image_bw)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDD992BFA50>
# Black Rectangle (Color)
# <PIL.Image.Image image mode=L size=512x512 at 0x7FDD992F72D0>
# Black Rectangle (B&W)

# %% [markdown]
# ### Let's draw a line over our black square
#
# cv2.line(image, starting cordinates, ending cordinates, color, thickness)

# %%
# Draw a diagonal blue line of thickness of 5 pixels

# Create our black canvas again
image = np.zeros((512,512,3), np.uint8)

# Coordinate: from 0 to 511
cv2.line(image, (0,0), (511,511), (255,127,0), 5)
cv.imshow("Blue Line", image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDD992F7E90>
# Blue Line

# %% [markdown]
# ### Let's now draw a rectangle
#
# cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)

# %%
# Draw a Rectangle 
image = np.zeros((512,512,3), np.uint8)

# Thickness - if positive. Negative thickness means that it is filled
cv2.rectangle(image, (100,100), (300,250), (127,50,127), 10)
cv.imshow("Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDD992B5AD0>
# Rectangle

# %% [markdown]
# ### How about cirlcles?
#
# cv2.cirlce(image, center, radius, color, fill)

# %%
image = np.zeros((512,512,3), np.uint8)

cv2.circle(image, (350, 350), 100, (15,75,50), -1) 
cv.imshow("Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDD99367E90>
# Circle

# %% [markdown]
# ## And polygons?
#
# cv2.polylines(image, points, Closed?, color, thickness)
#
# if Closed = True, we join the first and last point

# %%
image = np.zeros((512,512,3), np.uint8)

# Let's define four points
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)

# Let's now reshape our points in form  required by polylines
pts = pts.reshape((-1,1,2))

cv2.polylines(image, [pts], True, (0,0,255), 3)
cv.imshow("Polygon", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDD992AB810>
# Polygon

# %%
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)
pts.shape
# Out:
# (4, 2)

# %%
pts = pts.reshape((-1,1,2))
pts.shape
# Out:
# (4, 1, 2)

# %% [markdown]
# ### Let's even add text with cv2.putText
#
# cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)
#
# - FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# - FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# - FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# - FONT_HERSHEY_SCRIPT_SIMPLEX
# - FONT_HERSHEY_SCRIPT_COMPLEX

# %%
image = np.zeros((1000,1000,3), np.uint8)
ourString =  'Hello World!'
cv2.putText(image,ourString, (155,290), cv2.FONT_HERSHEY_SIMPLEX, 3, (240,170,0), 2)
cv.imshow("Hello World!", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7FDD992BD210>
# Hello World!

# %%
drive.flush_and_unmount()
